# %%
#imports
from vedo import *
import pandas as pd
from scipy.spatial import Delaunay
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
from itertools import product, combinations
from mpl_toolkits.mplot3d import Axes3D
    
embedWindow('k3d') # panel or itkwidgets or False (for a popup)
#import the file from github
###
    
#Load surfaces
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Toop.csv'
landSurfacePD =pd.read_csv(fileVertices)
#Load tops Wilcox
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Wilcox.csv'
vertices_Wilcox =pd.read_csv(fileVertices)
#Load tops Midway
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Midway.csv'
vertices_Midway =pd.read_csv(fileVertices)
#Load tops Navarro
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Navarro.csv'
vertices_Navarro =pd.read_csv(fileVertices)

#Load tops Taylor
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Taylor.csv'
vertices_Taylor =pd.read_csv(fileVertices)
#Load tops Austin_Chalk
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Austin_Chalk.csv'
vertices_AustinChalk =pd.read_csv(fileVertices)
#Load tops Anacacho
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Anacacho.csv'
vertices_Anacacho =pd.read_csv(fileVertices)

#Load tops Upper_Eagle_Ford
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Upper_Eagle_Ford.csv'
vertices_UpperEagleFord =pd.read_csv(fileVertices)
#Load tops Lower_Eagle_Ford
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Lower_Eagle_Ford.csv'
vertices_LowerEagleFord =pd.read_csv(fileVertices)
#Load tops Woodbine
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Woodbine.csv'
vertices_Woodbine =pd.read_csv(fileVertices)
#Load tops Maness
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Maness.csv'
vertices_Maness =pd.read_csv(fileVertices)
#Load tops Buda
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Buda.csv'
vertices_Buda =pd.read_csv(fileVertices)
#Load tops Del_Rio
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Del_Rio.csv'
vertices_DelRio =pd.read_csv(fileVertices)
#Load tops Georgetown
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Georgetown.csv'
vertices_Georgetown =pd.read_csv(fileVertices)
#Load tops Edwards
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Edwards.csv'
vertices_Edwards =pd.read_csv(fileVertices)
#Load tops Glen_Rose
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Glen_Rose.csv'
vertices_GlenRose =pd.read_csv(fileVertices)
#Load tops Pearsal
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Pearsal.csv'
vertices_Pearsal =pd.read_csv(fileVertices)
#Load tops James_Cow_Creek
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\James_Cow_Creek.csv'
vertices_JamesCowCreek =pd.read_csv(fileVertices)
#Load tops Cotton_Valley
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Cotton_Valley.csv'
vertices_CottonValley =pd.read_csv(fileVertices)
#Load tops Sligo
fileVertices = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\Sligo.csv'
vertices_Sligo =pd.read_csv(fileVertices)



#The well path and different logs for the well paths
filepath = 'C:\\Users\\Artur\\Desktop\\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\path5832.csv'
well_5832_path =pd.read_csv(filepath)

###Cities
file = 'C:\\Users\\Artur\Desktop\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\MinPointsWells_c.csv'
wellsminc =pd.read_csv(file)
file = 'C:\\Users\Artur\Desktop\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\MaxPointsWells_c.csv'
wellsmaxc =pd.read_csv(file)

#Since most of the wells in the area were just vertical, I split them into two files:
#One file with the top of the wells and the other with the bottom point of the wellbore
file = 'C:\\Users\\Artur\Desktop\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\MinPointsWells.csv'
wellsmin =pd.read_csv(file)
file = 'C:\\Users\Artur\Desktop\Geothermal energy and sustainable energy\\competition\\Data for Datathon\\Eaglebine\\Eaglebine\\tops\\MaxPointsWells.csv'
wellsmax =pd.read_csv(file)
# Out:
# embedWindow(verbose=True): could not load k3d module, try:
# > pip install k3d      # and if necessary:
# > conda install nodejs

# %%
# Create a plot
plot = Plotter(axes=1, bg='white', interactive=1)

####################
## 1. land surface
####################

#perform a 2D Delaunay triangulation to get the cells from the point cloud
tri = Delaunay(landSurfacePD.values[:, 0:2])
#create a mesh object for the land surface
landSurface = Mesh([landSurfacePD.values, tri.simplices])

#in order to color it by the elevation, we extract the z value
elevation = landSurface.cellCenters()[:, 2]   # pick z coordinates of cells

#unfortunatly I couldn't find a good colormap for terrain without ocean. 
#So we'll need to truncate the "terrain" color map
cmap = plt.get_cmap('terrain')
truncateMin = 0.23 #We want to start the colormap about a quarter of the way in until the end
truncateMax = 0.6
cmap_terrain_no_ocean = colors.LinearSegmentedColormap.from_list(
    'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=truncateMin, b=truncateMax),
    cmap(np.linspace(truncateMin, truncateMax, 10)))

#Now we color the cell by elevation
landSurface.cmap(cmap_terrain_no_ocean, elevation, on='cells')

#We give the object a name
landSurface.name='Land Surface'

#We add it to the plot
plot += landSurface

###
#Mesh of Wilcox
tri = Delaunay(vertices_Wilcox.values[:, 0:2])
vertices_Wilcox = Mesh([vertices_Wilcox.values, tri.simplices]).c("orange").opacity(0.2)
vertices_Wilcox.name='Wilcox_Top'
plot += vertices_Wilcox
#Mesh of Midway
tri = Delaunay(vertices_Midway.values[:, 0:2])
vertices_Midway = Mesh([vertices_Midway.values, tri.simplices]).c("yellow").opacity(0.2)
vertices_Midway.name='Midway_Top'
plot += vertices_Midway
#Mesh of Navarro
tri = Delaunay(vertices_Navarro.values[:, 0:2])
vertices_Navarro = Mesh([vertices_Navarro.values, tri.simplices]).c("blue").opacity(0.2)
vertices_Navarro.name='Navarro_Top'
plot += vertices_Navarro
#Mesh of Taylor
tri = Delaunay(vertices_Taylor.values[:, 0:2])
vertices_Taylor = Mesh([vertices_Taylor.values, tri.simplices]).c("grey").opacity(0.2)
vertices_Taylor.name='Taylor_Top'
plot += vertices_Taylor
#Mesh of Austin_Chalk
tri = Delaunay(vertices_AustinChalk.values[:, 0:2])
vertices_AustinChalk = Mesh([vertices_AustinChalk.values, tri.simplices]).c("violet").opacity(0.2)
vertices_AustinChalk.name='Austin_Chalk_Top'
plot += vertices_AustinChalk
#Mesh of Anacacho
tri = Delaunay(vertices_Anacacho.values[:, 0:2])
vertices_Anacacho = Mesh([vertices_Anacacho.values, tri.simplices]).c("black").opacity(0.2)
vertices_Anacacho.name='Anacacho_Top'
plot += vertices_Anacacho
#Mesh of Upper_Eagle_Ford
tri = Delaunay(vertices_UpperEagleFord.values[:, 0:2])
vertices_UpperEagleFord = Mesh([vertices_UpperEagleFord.values, tri.simplices]).c("red").opacity(0.2)
vertices_UpperEagleFord.name='Upper_Eagle_Ford_Top'
plot += vertices_UpperEagleFord
#Mesh of Lower_Eagle_Ford
tri = Delaunay(vertices_LowerEagleFord.values[:, 0:2])
vertices_LowerEagleFord = Mesh([vertices_LowerEagleFord.values, tri.simplices]).c("indigo").opacity(0.2)
vertices_LowerEagleFord.name='Lower_Eagle_Ford_Top'
plot += vertices_LowerEagleFord
#Mesh of Woodbine
tri = Delaunay(vertices_Woodbine.values[:, 0:2])
vertices_Woodbine = Mesh([vertices_Woodbine.values, tri.simplices]).c("red").opacity(0.2)
vertices_Woodbine.name='Woodbine_Top'
plot += vertices_Woodbine
#Mesh of Maness
tri = Delaunay(vertices_Maness.values[:, 0:2])
vertices_Maness = Mesh([vertices_Maness.values, tri.simplices]).c("yellow").opacity(0.2)
vertices_Maness.name='Maness_Top'
plot += vertices_Maness
#Mesh of Buda
tri = Delaunay(vertices_Buda.values[:, 0:2])
vertices_Buda = Mesh([vertices_Buda.values, tri.simplices]).c("orange").opacity(0.2)
vertices_Buda.name='Buda_Top'
plot += vertices_Buda
#Mesh of WDel_Rio
tri = Delaunay(vertices_DelRio.values[:, 0:2])
vertices_DelRio = Mesh([vertices_DelRio.values, tri.simplices]).c("green").opacity(0.2)
vertices_DelRio.name='DelRio_Top'
plot += vertices_DelRio
#Mesh of Georgetown
tri = Delaunay(vertices_Georgetown.values[:, 0:2])
vertices_Georgetown = Mesh([vertices_Georgetown.values, tri.simplices]).c("blue").opacity(0.2)
vertices_Georgetown.name='Georgetown_Top'
plot += vertices_Georgetown
#Mesh of Edwards
tri = Delaunay(vertices_Edwards.values[:, 0:2])
vertices_Edwards = Mesh([vertices_Edwards.values, tri.simplices]).c("black").opacity(0.2)
vertices_Edwards.name='Edwards_Top'
plot += vertices_Edwards
#Mesh of Glen_Rose
tri = Delaunay(vertices_GlenRose.values[:, 0:2])
vertices_GlenRose = Mesh([vertices_GlenRose.values, tri.simplices]).c("indigo").opacity(0.2)
vertices_GlenRose.name='GlenRose_Top'
plot += vertices_GlenRose
#Mesh of Pearsal
tri = Delaunay(vertices_Pearsal.values[:, 0:2])
vertices_Pearsal = Mesh([vertices_Pearsal.values, tri.simplices]).c("violet").opacity(0.2)
vertices_Pearsal.name='Pearsal_Top'
plot += vertices_Pearsal
#Mesh of James_Cow_Creek
tri = Delaunay(vertices_JamesCowCreek.values[:, 0:2])
vertices_JamesCowCreek = Mesh([vertices_JamesCowCreek.values, tri.simplices]).c("violet").opacity(0.2)
vertices_JamesCowCreek.name='JamesCowCreek_Top'
plot += vertices_JamesCowCreek
#Mesh of Cotton_Valley
tri = Delaunay(vertices_CottonValley.values[:, 0:2])
vertices_CottonValley = Mesh([vertices_CottonValley.values, tri.simplices]).c("violet").opacity(0.2)
vertices_CottonValley.name='CottonValley_Top'
plot += vertices_CottonValley



#Mesh of CSligo
tri = Delaunay(vertices_Sligo.values[:, 0:2])
vertices_Sligo = Mesh([vertices_Sligo.values, tri.simplices]).c("violet").opacity(0.2)
vertices_Sligo.name='Sligo_Top'
plot += vertices_Sligo



#The path of well 58_32
xyz = well_5832_path[['X', 'Y', 'Z']].values
Well = Line(xyz)
Well.name='Well 58-32'
#plot+=Well

#There is some preprocessing that needs to be done here in order to get two lists of points
#defining the start and end of the lines that will be representing the wellbores
xyzmin = wellsmin[['x', 'y', 'z']].values
xyzmax = wellsmax[['x', 'y', 'z']].values
p1=[]
p2=[]
for i in range(len(xyzmin)):
    p1.append(xyzmin[i,:])
    p2.append(xyzmax[i,:])

Wells = Lines(p1, p2, c='black', alpha=1000, lw=3)
Wells.name='Pre-existing wellbores'
plot+=Wells

#####Plot cities####

xyzmin = wellsminc[['x', 'y', 'z']].values
xyzmax = wellsmaxc[['x', 'y', 'z']].values
p1=[]
p2=[]
for i in range(len(xyzmin)):
    p1.append(xyzmin[i,:])
    p2.append(xyzmax[i,:])

Cities = Lines(p1, p2, c='red', alpha=1, lw=10)
Cities.name='Pre-existing'
plot+=Cities

##########
f = "San Antonio"
f1 = "New Braunfels"
f2 = "Austin"
f3 = "Georgetown"
f4 = "Temple"
f5 = "College Station"


formula = Latex(f, c='k', s=0.5).rotateX(90).rotateZ(270).pos(30.0,99.5,0.01)
formula1 = Latex(f1, c='k', s=0.5).rotateX(90).rotateZ(270).pos(30.2,99.1,0.01)

formula2 = Latex(f2, c='k', s=0.5).rotateX(90).rotateZ(270).pos(31.0,98.5,0.01)
formula3 = Latex(f3, c='k', s=0.5).rotateX(90).rotateZ(270).pos(31.1,98.4,0.2)
formula4 = Latex(f4, c='k', s=0.5).rotateX(90).rotateZ(270).pos(31.5,98.2,0.01)
formula5 = Latex(f5, c='k', s=0.5).rotateX(90).rotateZ(270).pos(31.2,97.1,0.01)
#show(histo, formula, axes=1, viewup='z')


## 6. Done. show the plot

plot.show(formula4, landSurface,formula5, formula3, formula2,vertices_Wilcox, vertices_AustinChalk,vertices_Navarro,vertices_Midway, vertices_Taylor, vertices_Anacacho,vertices_UpperEagleFord,vertices_LowerEagleFord, formula1,vertices_Woodbine,vertices_Maness,vertices_Georgetown,vertices_Buda,vertices_DelRio, vertices_Edwards,vertices_JamesCowCreek,vertices_GlenRose, vertices_Pearsal, vertices_Sligo,vertices_CottonValley, formula, Cities, Wells, viewup='z')
